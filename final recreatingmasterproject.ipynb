# %% [markdown]
# <a href="https://colab.research.google.com/github/bjkc/Data-visualization/blob/main/final%20recreatingmasterproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bijay raj kc
#
# CPSMA 4313
#
# RECREATING THE MASTER PROJECT

# %% [markdown]
# For this recreating project i have choosen the video games.My topic will be the most valuable video game companies in the world and its revenue in billion.I Choose the video games topic for this project because i have been playing video games since i was a kid and still spend some times playing it now.
#
# ![20180514_Games_Revenue.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# I have found the above data on forbes which is showing the revenue of the video games companies.And below is the another graph which looks more informative than above
#
# ![Newzoo_Top_10_Companies_by_Game_Revenues.png](data:image/png;base64,...)

# %% [markdown]
# recreating will be hard but lets do the work by putting the code that i have been using the whole semister in many quizes and exam has been using this code

# %%
import numpy as np #a matrix like package for handling data
import pandas as pa #a R like package for handling data
from scipy import stats #a way to just get a piece of a large package
import matplotlib.pyplot as plt #a way to generate plots, histograms, bar charts, and other types of charts 
import seaborn as sns #it is based on matplotlib
import requests #HTTP library
import pandas as pd # used to manipulate data and analyze it
from bs4 import BeautifulSoup #Used for a web scraping purposes to pull the data out of HTML and XML files
import re #Used for regular expression in Python.

# %%
r = requests.get('https://en.wikipedia.org/wiki/Video_game_publisher')
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")
len(html_soup.find_all('table'))
# Out:
# 4

# %%
html_soup.title
# Out:
# <title>Video game publisher - Wikipedia</title>

# %%
tables = html_soup.find_all('table')

df = pa.read_html(str(tables))[2]
df
# Out:
#     FY 2020-2021               Name of Publisher            HQ Country  \
# 0              1  Sony Interactive Entertainment  Japan, United States
# 1              2                   Tencent Games                 China
# 2              3                        Nintendo                 Japan
# 3              4                       Microsoft         United States
# 4              5                         NetEase                 China
# 5              6             Activision Blizzard         United States
# 6              7                 Electronic Arts         United States
# 7              8            Take-Two Interactive         United States
# 8              9                    Bandai Namco                 Japan
# 9             10                     Square Enix                 Japan
# 10            11                           Nexon    South Korea, Japan
# 11            12                       Netmarble           South Korea
# ...

# %% [markdown]
# Lets see if i have some null values so i can clean them .This is what i will be doing now

# %%
ax = sns.barplot(data = df, x= 'Name of Publisher', y= "Revenue in $bn", hue_order= None )
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
ax.set_title('The Most Valuable Video Game Companies')
plt.show()

# %% [markdown]
# i tried to recreate it and offcourse i will do some more with data cleaning and recreate the best one for the project

# %%
df.isnull()
# Out:
#     FY 2020-2021  Name of Publisher  HQ Country  Revenue in $bn
# 0          False              False       False           False
# 1          False              False       False           False
# 2          False              False       False           False
# 3          False              False       False           False
# 4          False              False       False           False
# 5          False              False       False           False
# 6          False              False       False           False
# 7          False              False       False           False
# 8          False              False       False           False
# 9          False              False       False           False
# 10         False              False       False           False
# 11         False              False       False           False
# 12         False              False       False           False
# 13         False              False       False           False
# ...

# %% [markdown]
# Yes i need to do data cleaning as much as i can so it looks great for data visualization and i will be continuing creating the best one and i will recreate the first picture

# %% [markdown]
# so okay lets clean the column

# %%
df.columns
# Out:
# Index(['FY 2020-2021', 'Name of Publisher', 'HQ Country', 'Revenue in $bn'], dtype='object')

# %% [markdown]
# now ,from here  we can see there are [], (), %. Let's clean (%) part from the column and any other special character between them.

# %%
cols = df.columns.map(lambda s: re.sub(r"[(.())./d]","",s))
cols
# Out:
# Index(['FY 2020-2021', 'Name of Publisher', 'HQ Country', 'Revenue in $bn'], dtype='object')

# %%
df.columns = df.columns.map(lambda s: re.sub(r"[.\d[(.$M%\d)\]]","",s))

# %% [markdown]
# i will again make sure the data is cleaned properly.

# %%
df.columns
# Out:
# Index(['FY -', 'Name of Publisher', 'HQ Country', 'Revenue in bn'], dtype='object')

# %% [markdown]
# i still need to clean the space

# %%
cols1 = df.columns.map(lambda s: re.sub(r" ","",s))
cols1
# Out:
# Index(['FY-', 'NameofPublisher', 'HQCountry', 'Revenueinbn'], dtype='object')

# %%
df.columns = df.columns.map(lambda s: re.sub(r" ","",s))

# %%
df.columns
# Out:
# Index(['FY-', 'NameofPublisher', 'HQCountry', 'Revenueinbn'], dtype='object')

# %%
Team = df.NameofPublisher.map (lambda s: s.upper())

# %%
df.NameofPublisher =df.NameofPublisher.map(lambda s: s.upper())

# %% [markdown]
# now i will apply this changes to my old table and do visualization

# %%
plt.rcParams["figure.figsize"] = [15, 8]
plt.rcParams["figure.autolayout"] = True
ax = sns.barplot(data = df, x = 'NameofPublisher', y= "Revenueinbn", ci= None)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 60)
#ylabels = ['0','$3Bn' , '$6Bn', '$8Bn', '$12Bn', '$14Bn', '$15.5nB', '$16Bn', '$18Bn']
ax.set_title('The Most Valuable Video Game Companies')
#ax.set_yticklabels(ylabels)
plt.show()

# %% [markdown]
# lets see the above graph in different colors and also my graph have correct name but the biggest problem is its not vertical so lets recreate that and make it right

# %%
plt.rcParams["figure.figsize"] = [10, 7]
plt.rcParams["figure.autolayout"] = True
sns.set_style('ticks')
ax = sns.barplot(data = df, y = 'NameofPublisher', x= "Revenueinbn", color= 'Red', ci= None, linewidth= 0.5)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 60)
ylabels = ['0','$3Bn' , '$6Bn', '$8Bn', '$12Bn', '$14Bn', '$15.5nB', '$16Bn', '$18Bn']
ax.set_yticklabels(ylabels)
ax.set_title('The Most Valuable Video Game Companies')
sns.despine()
plt.show()

# %% [markdown]
# by the way i like those bright colors butthe name of publisher is misplaced so lets fix it

# %%
plt.rcParams["figure.figsize"] = [15, 8]
plt.rcParams["figure.autolayout"] = True
sns.set_style('ticks')
ax = sns.barplot(data = df, y = 'NameofPublisher', x= "Revenueinbn", color= 'darkred', ci= None, linewidth = 0.5)
ax.set_title('The Most Valuable Video Game Companies ',size = float(35.0), fontweight = 'bold')
sns.despine()
plt.show()

# %%
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox #AnnotationBbox creates an annotation using an OffsetBox,

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
arr_lena = plt.imread('/content/download.png')
newax = fig.add_axes([-0.07,0.85,0.2,0.2], anchor='NE', zorder=1)
newax.imshow(arr_lena)
newax.axis('off')
plt.draw()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py:125: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
arr_lena = plt.imread('/apple.png')
newax = fig.add_axes([-0.07,0.85,0.2,0.2], anchor='NE', zorder=1)
newax.imshow(arr_lena)
newax.axis('off')
plt.draw()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py:125: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# i tried to play and make it with the logo but coudnt figure it out and i dont want mess up by graph

# %%
ax = sns.barplot(data = df, y = 'NameofPublisher', x= "Revenueinbn", color= 'green', ci= None, linewidth = 0.5)
#ax.set_xticklabels(ax.get_xticklabels(),rotation = 60)
#ylabels = ['0','$3Bn' , '$6Bn', '$8Bn', '$12Bn', '$14Bn', '$15.5Bn', '$16Bn', '$18Bn']
#ax.set_yticklabels(ylabels)
ax.set_title('The Most Valuable Video Game Companies ',size = float(35.0), fontweight = 'bold')
sns.despine()
plt.show()

# %% [markdown]
# lets do it with one more time with little change and color

# %%
plt.rcParams["figure.figsize"] = [15, 10]
plt.rcParams["figure.autolayout"] = True
sns.set_style('ticks')
ax = sns.barplot(data = df, y = 'NameofPublisher', x= "Revenueinbn", color= 'purple', ci= None, linewidth = 0.5)
#ax.set_xticklabels(ax.get_xticklabels(),rotation = 60)
#ylabels = ['0','$3Bn' , '$6Bn', '$8Bn', '$12Bn', '$14Bn', '$15.5Bn', '$16Bn', '$18Bn']
#ax.set_yticklabels(ylabels)
ax.set_title('The Most Valuable Video Game Companies ',size = float(35.0), fontweight = 'bold')
sns.despine()
plt.show()

# %% [markdown]
# And yes recreating is not easy as it seems the graph above needs logo too i will still try and make the recreation as close as possible  . lets put the code and bring the logo in all the companies name and update the visualization graph as close asi can make.

# %%
plt.rcParams["figure.figsize"] = [15, 8]
plt.rcParams["figure.autolayout"] = True
sns.set_style('ticks')
ax = sns.barplot(data = df, y = 'NameofPublisher', x= "Revenueinbn", color= 'steelblue', ci= None, linewidth = 0.5)
ax.set_title('The Most Valuable Video Game Companies ',size = float(35.0), fontweight = 'bold')
arr_lena = plt.imread("/activisionblizard.png")








arr_lena5 = plt.imread("/download.png")
axin = ax.inset_axes([-0.11,0.94,0.099,0.05], anchor='NE', zorder=1)    
axin.imshow(arr_lena5)
axin.axis('OFF')



arr_lena17 = plt.imread("/tencentgames.jpg")
axin = ax.inset_axes([-0.11,0.87,0.099,0.06], anchor='NE', zorder=1)    
axin.imshow(arr_lena17)
axin.axis('OFF')




arr_lena14 = plt.imread("/nintendo.png")
axin = ax.inset_axes([-0.11,0.83,0.099,0.05], anchor='NE', zorder=1)    
axin.imshow(arr_lena14)
axin.axis('OFF')


arr_lena10 = plt.imread("/microsoft.png")
axin = ax.inset_axes([-0.11,0.77,0.099,0.06], anchor='NE', zorder=1)    
axin.imshow(arr_lena10)
axin.axis('OFF')



arr_lena11 = plt.imread("/netease.png")
axin = ax.inset_axes([-0.11,0.72,0.099,0.04], anchor='NE', zorder=1)    
axin.imshow(arr_lena11)
axin.axis('OFF')


arr_lena1= plt.imread('/activisionblizard.png')
axin = ax.inset_axes([-0.11,0.67,0.099,0.06], anchor='NE', zorder=1)  
axin.imshow(arr_lena1)
axin.axis('OFF')



arr_lena6 = plt.imread("/electronicart.png")
axin = ax.inset_axes([-0.11,0.58,0.099,0.06], anchor='NE', zorder=1)    
axin.imshow(arr_lena6)
axin.axis('OFF')




arr_lena16 = plt.imread("/take2.png")
axin = ax.inset_axes([-0.11,0.52,0.099,0.07], anchor='NE', zorder=1)    
axin.imshow(arr_lena16)
axin.axis('OFF')



arr_lena3 = plt.imread("/bandainamco.png")
axin = ax.inset_axes([-0.11,0.47,0.099,0.08], anchor='NE', zorder=1)    
axin.imshow(arr_lena3)
axin.axis('OFF')





arr_lena16 = plt.imread("/squareenix.png")
axin = ax.inset_axes([-0.11,0.4,0.099,0.05], anchor='NE', zorder=1)    
axin.imshow(arr_lena16)
axin.axis('OFF')





arr_lena13 = plt.imread("/nexon.jpg")
axin = ax.inset_axes([-0.11,0.34,0.099,0.05], anchor='NE', zorder=1)    
axin.imshow(arr_lena13)
axin.axis('OFF')





arr_lena12 = plt.imread("/netmarble.jpg")
axin = ax.inset_axes([-0.10,0.29,0.099,0.07], anchor='NE', zorder=1)    
axin.imshow(arr_lena12)
axin.axis('OFF')


arr_lena17 = plt.imread("/ubisoft.jpg")
axin = ax.inset_axes([-0.11,0.24,0.099,0.04], anchor='NE', zorder=1)    
axin.imshow(arr_lena17)
axin.axis('OFF')

arr_lena9 = plt.imread("/konabi.png")
axin = ax.inset_axes([-0.11,0.18,0.099,0.04], anchor='NE', zorder=1)    
axin.imshow(arr_lena9)
axin.axis('OFF')

arr_lena15 = plt.imread("/sega.png")
axin = ax.inset_axes([-0.11,0.12,0.099,0.05], anchor='NE', zorder=1)    
axin.imshow(arr_lena15)
axin.axis('OFF')

arr_lena4 = plt.imread("/capcom.png")
axin = ax.inset_axes([-0.11,0.06,0.099,0.04], anchor='NE', zorder=1)
axin.imshow(arr_lena4)
axin.axis('OFF')

arr_lena7 = plt.imread("/embracer.png")
axin = ax.inset_axes([-0.11,0.007,0.099,0.05], anchor='NE', zorder=1)    
axin.imshow(arr_lena7)
axin.axis('OFF')

ax.set_yticklabels([])
sns.despine()
plt.show()

# %% [markdown]
# Honestly the above graphs in as close as possible i can make color looks great in my visualization but i couldnt make it as perfect and the value in the right place and logo at the same time but still did my best for the visualization.
#
#
#
# At the end i have recreated the graph as much close as it can be with my work and effort but can admit can be more exactly be the same than mine. i was having very hard time in putting x axis and y axis in correct order to put the revenue value in billion but did correct after few errors.My main chalanges was put the correct value of the company and put the size of logo in correct place.
