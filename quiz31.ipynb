# %% [markdown]
# <a href="https://colab.research.google.com/github/bjkc/Data-visualization/blob/main/quiz31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #bijay raj kc
#
# quiz 31
#
# bijay raj kc

# %% [markdown]
# I am going to write about playstation the video games which is the most popular in todays digital world and the growth of the video games and its popularity. I am still doubtful if it is good for visualization.I am interested in this because digital games are so popular thats people of all ages enjoy playing that for so many reasons  and i have been playing it since i was a kid.

# %% [markdown]
# Here are the popular link to my topic which gave me more idea
#
#
#
# https://en.wikipedia.org/wiki/PlayStation
#
# https://www.ign.com/articles/2018/11/08/playstation-now-is-more-popular-thank-you-think
#
#
# https://www.ign.com/articles/why-digital-sales-could-totally-dominate-physical-formats-in-just-a-few-years

# %% [markdown]
# ![game.jpeg](data:image/jpeg;base64,...)
