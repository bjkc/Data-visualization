# %% [markdown]
# <a href="https://colab.research.google.com/github/bjkc/Data-visualization/blob/main/SQL%20joins%20quiz6bijay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #bijay raj kc quiz6
# SQL joins

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project data-visualization-bjkc
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# LIMIT 10
# Out:
#       trip_id  ... duration_minutes
# 0  9900289692  ...               39
# 1  9900285987  ...               31
# 2  9900285989  ...               31
# 3  9900285991  ...               30
# 4  9900286140  ...               19
# 5  9900286143  ...               17
# 6  9900286171  ...                6
# 7  9900286214  ...                0
# 8  9900286540  ...               12
# 9    13575843  ...               47
#
# [10 rows x 9 columns]

# %%
# %%bigquery --project data-visualization-bjkc
#
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_stations`
# limit 5
# Out:
#    station_id  ...             modified_date
# 0        3464  ... 2021-01-04 12:00:00+00:00
# 1        2500  ... 2021-01-04 12:00:00+00:00
# 2        2536  ... 2021-01-04 12:00:00+00:00
# 3        2538  ... 2021-01-04 12:00:00+00:00
# 4        2541  ... 2021-01-04 12:00:00+00:00
#
# [5 rows x 14 columns]

# %%
# %%bigquery --project data-visualization-bjkc
#
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# where start_station_name = 'parkland'
# limit 5
# Out:
# Empty DataFrame
# Columns: [trip_id, subscriber_type, bikeid, start_time, start_station_id, start_station_name, end_station_id, end_station_name, duration_minutes]
# Index: []

# %%
# %%bigquery --project data-visualization-bjkc
#
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_stations`
# where property_type = 'sidewalk'
# limit 5
# Out:
#    station_id  ...             modified_date
# 0        1111  ... 2021-11-04 02:12:00+00:00
# 1          11  ... 2021-11-04 02:24:00+00:00
# 2        4699  ... 2021-07-27 08:25:00+00:00
# 3        2570  ... 2021-01-04 12:00:00+00:00
# 4        2496  ... 2021-01-04 12:00:00+00:00
#
# [5 rows x 14 columns]

# %%
# %%bigquery --project data-visualization-bjkc
# WITH t as(
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_stations`
# WHERE property_type = 'sidewalk')
#
# SELECT *
# FROM t as table1 JOIN `bigquery-public-data.austin_bikeshare.bikeshare_trips` as table2 ON table1.name = table2.start_station_name
# LIMIT 5
# Out:
#    station_id  ... duration_minutes
# 0        3291  ...               20
# 1        3291  ...               35
# 2        3291  ...               19
# 3        3291  ...                7
# 4        3294  ...               17
#
# [5 rows x 23 columns]

# %%
# %%bigquery --project data-visualization-bjkc
# SELECT type.station_id,type.name, type.property_type,trips.start_station_name,trips.end_station_name
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips` as trips LEFT OUTER JOIN `bigquery-public-data.austin_bikeshare.bikeshare_stations` as type
#           on trips.start_station_name = type.name
# LIMIT 50
# Out:
#     station_id  ...                                   end_station_name
# 0         1006  ...                                       Nueces @ 3rd
# 1         2712  ...                            Toomey Rd @ South Lamar
# 2         2712  ...                            Toomey Rd @ South Lamar
# 3         2712  ...                            Toomey Rd @ South Lamar
# 4         2541  ...                    State Capitol @ 14th & Colorado
# 5         2541  ...                    State Capitol @ 14th & Colorado
# 6         2536  ...                                   Waller & 6th St.
# 7         2712  ...                            Toomey Rd @ South Lamar
# 8         2536  ...                                   Waller & 6th St.
# 9         3464  ...                                         Pease Park
# 10        2541  ...                    State Capitol @ 14th & Colorado
# 11        2541  ...                    State Capitol @ 14th & Colorado
# ...
