# %% [markdown]
# <a href="https://colab.research.google.com/github/bjkc/Data-visualization/blob/main/recentvisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bijay raj kc
#
# CPSMA 4313
#
#
#
# #                    The Top global causes of death
#
#
#
#
#
# ABSTRACT:WHO’s Global Health Estimates provide the latest available data on causes of death  globally, by region and country, and by age, sex and income group. They provide key insights on mortality and morbidity trends to support informed decision-making on health policy and resource allocation.These data are relied on by researchers, epidemiologists, clinicians, policymakers, and many others working to identify problems, find solutions, and save lives.

# %% [markdown]
# Intro:-
#
# It is Very much important to know why people die to improve how people live. When we measure how many people die each year then it can help us to assess the effectiveness of our health systems and direct resources to where they are needed most. For example, mortality data can help focus activities and resource allocation among sectors such as transportation, food and agriculture, and the environment as well as health.

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup
r = requests.get("https://en.wikipedia.org/wiki/List_of_causes_of_death_by_rate")
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")

# %%
tables = html_soup.find_all('table')
df = pa.read_html(str(tables))[8]
df.head(10)
# Out:
#   Causes of death in developing countries  Number of deaths  \
# 0                                HIV-AIDS           2678000
# 1            Lower respiratory infections           2643000
# 2                 Ischaemic heart disease           2484000
# 3                                Diarrhea           1793000
# 4                 Cerebrovascular disease           1381000
# 5                      Childhood diseases           1217000
# 6                                 Malaria           1103000
# 7                            Tuberculosis           1021000
# 8   Chronic obstructive pulmonary disease            748000
# 9                                 Measles            674000
#
#   Causes of death in developed countries  Number of deaths.1
# 0                Ischaemic heart disease             3512000
# 1                Cerebrovascular disease             3346000
# 2  Chronic obstructive pulmonary disease             1829000
# ...

# %% [markdown]
# I have pulled the above data from the wikipedia for that i have used the soup command i found this table more information because it not only have the causes of death but also the number of death from the diseases in developed and developing countries.
#
#
#
# ![1200px-Leading_cause_of_death_world.png](data:image/png;base64,...)
#
#
#
#
# WHO(world health organisation)
# Why i have used the WHO?
# -Because the WHO has played a leading role in several public health achievements,and in public health it is shaping the research agenda and stimulating the generation, translation, and dissemination of valuable knowledge. It also provides technical assistance to countries, sets international health standards, and collects data on global health issues.And i have chooses there top global causes of death from which millions of people worldwide are loosing their lifes.

# %% [markdown]
# CDC(Centers of disease control and prevention)
#
# CDC is the nation’s leading science-based, data-driven, service organization that protects the public’s health. For more  years, they have put science into action to help the community stay healthy so they can grow and learn; to help families, businesses, and communities fight disease and stay strong; and to protect the public’s health.
#
#
# ![causesofdeath.png](data:image/png;base64,...)
#
#
# ![db427-fig4.gif](data:image/gif;base64,...)

# %% [markdown]
# Why should both of the graph be considered as a great visualization? What are the similarities?
#
# I think both of the graph is great for visualization as they both have the knowledgable information of the topic in different but correct way. They both have the bar plot and showing the causes of death. They both are also labelled in a correct unit both have shown the topic in a systematic manner.

# %% [markdown]
# Graphical Excellence of Both Graph
#
#  The excellence in statistical graphics consists of complex ideas communicated with clarity, precision, and efficacy.It is a technique to make critics in graphs
#  The graphical excellence consists of
#  -encourage the eye to compare different pieces of data
#  -reveal the data in multiple levels of detail
#  -serve a reasonably clear purpose
#
#
# There is a graphical excellence in both graphs it gives the viewers the great ideas of the topic in a simple and understandable way.It is also closely integrated with the statistical and verbal descriptions of the data set.

# %% [markdown]
# What can we say about the presentation of data in the graph?
# -The graph is well defined and also as we can clearly see its a bar graph.It is providing the information of the topic in a very efficent manner and reveal the data in multiple levels of detail

# %% [markdown]
# The information on the graph
# -It have all the information of the topic in a clear and deatail way and it present many good information  in a small space.IT have provided the topic in the graph with  ideas communicated with clarity, precision and efficiency.

# %% [markdown]
# Visulization impact
#
# The first graph have more causes of death as it is the topic the second one have less but still both are informative in many ways in their own way.

# %% [markdown]
# Conclusion
# -National data on leading causes of death are used to monitor trends, recognize emerging challenges, track the effectiveness of interventions, and make public health decisions that improve and save lives. I Have presented two bar graphs and the table related with it

# %% [markdown]
# Reference:
#
# https://www.cdc.gov/nchs/products/databriefs/db427.htm
#
# https://www.who.int/news-room/fact-sheets/detail/the-top-10-causes-of-death
#
# https://ourworldindata.org/causes-of-death
#
# https://www.statista.com/statistics/288839/leading-causes-of-death-worldwide/
#
# https://www.cdc.gov/nchs/fastats/deaths.htm
#
# https://www.who.int/data/gho/data/themes/mortality-and-global-health-estimates
#
# https://wonder.cdc.gov/wonder/help/ucd.html
