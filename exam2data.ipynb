# %% [markdown]
# <a href="https://colab.research.google.com/github/bjkc/Data-visualization/blob/main/exam2data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exam2
#
# data visualization CPSMA 4313
#
#
# Bijay raj kc

# %% [markdown]
# #for this exam first i will be gathering data from fitbit first on provided in kaggle and in the github repo and i have used the following resources for this exam:-
#
#
#          https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv
#
#          https://www.tutorialspoint.com/python_pandas/python_pandas_dataframe.htm
#
#          https://www.w3schools.com/python/pandas/pandas_dataframes.asp
#
#
#          https://github.com/nurfnick/Data_Viz/blob/main/01_Python.ipynb
#
#
#           https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb
#
#
#            https://github.com/nurfnick/Data_Viz/blob/main/18_One_Hot_Encoding.
#            ipynb
#
#            https://stackoverflow.com/questions/62380047/python-dataframe-problems
#
#
#
#
#
#            I ATTEST THAT THE RESOURCES ABOVE WERE THE ONLY ONES UTILIZED IN   COMPLETING THE EXAM AND THE WORK INCLUDED IS MY OWN AND NO ONE ELSE FROM THE  COURSE.
#
#            Mostly this exam is about data cleaning and how to handle it and managing and removing all the extra characters which is not needed

# %%
import numpy as np #a matrix like package for handling data
import pandas as pd #a R like package for handling data
from scipy import stats #gives a piece of a large package
import matplotlib.pyplot as plt #a way to generate plots, histograms, bar charts, etc 
import seaborn as sns #it is based on matplotlib
import requests #HTTP library
import pandas as pd #  manipulate data and analyze it
from bs4 import BeautifulSoup #Used for a web scraping purposes 
import re #Used for regular expression in Python.

# %% [markdown]
# The libraries that i have used to complete this exam are listed above

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv")
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# Above the data is stored in a pandas dataframe

# %%
df.tail()
# Out:
#      Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 995         995   2022-02-14   Pool Swimming      6.92   101       313
# 996         996   2022-02-14       Freestyle      9.48    61       219
# 997         997   2022-02-14       Freestyle      3.30    40       169
# 998         998   2022-02-14  Indoor Cycling      4.40    47        52
# 999         999   2022-02-14  Indoor Cycling      1.57   116       106
#
#      total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 995          NaN      28.66       173.30       234.73  ...      NaN      NaN
# 996          NaN       9.23       114.34       109.32  ...      NaN      NaN
# 997          NaN       7.37       133.97       122.96  ...      NaN      NaN
# 998          NaN      10.75       147.65       116.51  ...      NaN      NaN
# 999          NaN      25.37       143.41       182.80  ...      NaN      NaN
#
# ...

# %% [markdown]
# in the above code df.tail() it is helping to get the last five dataset which is very helpful to get last five dataset very fast.

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# activity_day       object
# workout_type       object
# distance          float64
# time                int64
# calories            int64
# total_steps       float64
# avg_speed         float64
# avg_cadence       float64
# max_cadence       float64
# avg_pace           object
# max_pace           object
# min_pace           object
# avg_heart_rate    float64
# max_heart_rate    float64
# min_heart_rate      int64
# vo2_max(%)          int64
# aerobic(%)          int64
# anaerobic(%)        int64
# intensive(%)        int64
# light(%)            int64
# dtype: object

# %% [markdown]
# the code above df.dtypes is giving the data like int64,float64 and object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1000 non-null   int64
#  1   activity_day    1000 non-null   object
#  2   workout_type    1000 non-null   object
#  3   distance        1000 non-null   float64
#  4   time            1000 non-null   int64
#  5   calories        1000 non-null   int64
#  6   total_steps     554 non-null    float64
#  7   avg_speed       1000 non-null   float64
#  8   avg_cadence     1000 non-null   float64
#  9   max_cadence     1000 non-null   float64
#  10  avg_pace        554 non-null    object
#  11  max_pace        554 non-null    object
#  12  min_pace        554 non-null    object
#  13  avg_heart_rate  1000 non-null   float64
#  14  max_heart_rate  1000 non-null   float64
#  15  min_heart_rate  1000 non-null   int64
#  16  vo2_max(%)      1000 non-null   int64
# ...

# %% [markdown]
# The above table needs some cleaning as we can see there are a repeated indexes

# %%
df1 = pd.DataFrame(df)

for col in df1.columns:

    if 'Unnamed: 0' in col:

        del df1[col]

# %%
df1.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          NaN
# 1   2022-01-01       Freestyle      3.44    96        55          NaN
# 2   2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          NaN
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# Now i will be removing one particular column with the help of the code below

# %%
df.drop(['Unnamed: 0'], axis = 1)
# Out:
#     activity_day    workout_type  distance  time  calories  total_steps  \
# 0     2022-01-01       Freestyle      9.30    77       123          NaN
# 1     2022-01-01       Freestyle      3.44    96        55          NaN
# 2     2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3     2022-01-01         Walking      7.91    42        82       1571.0
# 4     2022-01-01      Open Water      8.99    36       131          NaN
# ..           ...             ...       ...   ...       ...          ...
# 995   2022-02-14   Pool Swimming      6.92   101       313          NaN
# 996   2022-02-14       Freestyle      9.48    61       219          NaN
# 997   2022-02-14       Freestyle      3.30    40       169          NaN
# 998   2022-02-14  Indoor Cycling      4.40    47        52          NaN
# 999   2022-02-14  Indoor Cycling      1.57   116       106          NaN
#
#      avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# ...

# %% [markdown]
# Above i have dropped down  the Unnamed: 0 column. And to apply the command we have to pass it from the df so that it will give the updated  df table.

# %%
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# And we can the updated one above

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'activity_day', 'workout_type', 'distance', 'time',
#        'calories', 'total_steps', 'avg_speed', 'avg_cadence', 'max_cadence',
#        'avg_pace', 'max_pace', 'min_pace', 'avg_heart_rate', 'max_heart_rate',
#        'min_heart_rate', 'vo2_max(%)', 'aerobic(%)', 'anaerobic(%)',
#        'intensive(%)', 'light(%)'],
#       dtype='object')

# %% [markdown]
# Again i am doing some cleaning here mostly i am cleaning(%) part

# %%
cols = df.columns.map(lambda s: re.sub(r"[(.%)]","",s))
cols
# Out:
# Index(['Unnamed: 0', 'activity_day', 'workout_type', 'distance', 'time',
#        'calories', 'total_steps', 'avg_speed', 'avg_cadence', 'max_cadence',
#        'avg_pace', 'max_pace', 'min_pace', 'avg_heart_rate', 'max_heart_rate',
#        'min_heart_rate', 'vo2_max', 'aerobic', 'anaerobic', 'intensive',
#        'light'],
#       dtype='object')

# %%
df.columns = df.columns.map(lambda s: re.sub(r"[(.%)]","",s))

# %%
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max  aerobic  anaerobic  \
# ...

# %% [markdown]
# We can see the cleaned column above

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# activity_day       object
# workout_type       object
# distance          float64
# time                int64
# calories            int64
# total_steps       float64
# avg_speed         float64
# avg_cadence       float64
# max_cadence       float64
# avg_pace           object
# max_pace           object
# min_pace           object
# avg_heart_rate    float64
# max_heart_rate    float64
# min_heart_rate      int64
# vo2_max             int64
# aerobic             int64
# anaerobic           int64
# intensive           int64
# light               int64
# dtype: object

# %% [markdown]
# again the code above df.dtypes is giving the data like int64,float64 and object but now we are converting the activity_day into the datetime format

# %%
pd.to_datetime(df.activity_day, format='%Y-%m-%d')
# Out:
# 0     2022-01-01
# 1     2022-01-01
# 2     2022-01-01
# 3     2022-01-01
# 4     2022-01-01
#          ...
# 995   2022-02-14
# 996   2022-02-14
# 997   2022-02-14
# 998   2022-02-14
# 999   2022-02-14
# Name: activity_day, Length: 1000, dtype: datetime64[ns]

# %% [markdown]
# i will be putting correct format now so it will assigned to datetime because we can see above it is not done yet

# %%
df.activity_day = pd.to_datetime(df.activity_day, format='%Y-%m-%d')

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# activity_day      datetime64[ns]
# workout_type              object
# distance                 float64
# time                       int64
# calories                   int64
# total_steps              float64
# avg_speed                float64
# avg_cadence              float64
# max_cadence              float64
# avg_pace                  object
# max_pace                  object
# min_pace                  object
# avg_heart_rate           float64
# max_heart_rate           float64
# min_heart_rate             int64
# vo2_max                    int64
# aerobic                    int64
# anaerobic                  int64
# intensive                  int64
# light                      int64
# dtype: object

# %% [markdown]
# we can see the changes to datetime format above

# %%
df.total_steps.fillna(0)
# Out:
# 0         0.0
# 1         0.0
# 2         0.0
# 3      1571.0
# 4         0.0
#         ...
# 995       0.0
# 996       0.0
# 997       0.0
# 998       0.0
# 999       0.0
# Name: total_steps, Length: 1000, dtype: float64

# %% [markdown]
# Now we can see all the NaN is now filled with 0's

# %%
df.total_steps = df.total_steps.fillna(0)

# %% [markdown]
# Now my table will be more clean than before

# %%
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          0.0      18.88       168.54       138.30  ...      NaN      NaN
# 1          0.0      29.65       125.92       292.81  ...      NaN      NaN
# 2          0.0      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          0.0      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max  aerobic  anaerobic  \
# ...

# %%
df.avg_pace = df.avg_pace.fillna(0)

# %%
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          0.0      18.88       168.54       138.30  ...      NaN      NaN
# 1          0.0      29.65       125.92       292.81  ...      NaN      NaN
# 2          0.0      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          0.0      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max  aerobic  anaerobic  \
# ...

# %%
#df.avg_pace = df['avg_pace'].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1000 non-null   int64
#  1   activity_day    1000 non-null   datetime64[ns]
#  2   workout_type    1000 non-null   object
#  3   distance        1000 non-null   float64
#  4   time            1000 non-null   int64
#  5   calories        1000 non-null   int64
#  6   total_steps     1000 non-null   float64
#  7   avg_speed       1000 non-null   float64
#  8   avg_cadence     1000 non-null   float64
#  9   max_cadence     1000 non-null   float64
#  10  avg_pace        1000 non-null   object
#  11  max_pace        554 non-null    object
#  12  min_pace        554 non-null    object
#  13  avg_heart_rate  1000 non-null   float64
#  14  max_heart_rate  1000 non-null   float64
#  15  min_heart_rate  1000 non-null   int64
#  16  vo2_max         1000 non-null   int64
# ...

# %%
pd.to_numeric(df.avg_pace, errors ='ignore')
# Out:
# 0          0
# 1          0
# 2          0
# 3      07:58
# 4          0
#        ...
# 995        0
# 996        0
# 997        0
# 998        0
# 999        0
# Name: avg_pace, Length: 1000, dtype: object

# %%
df.groupby('workout_type').agg(['mean','median','count','std'])
# Out:
#                  Unnamed: 0                           distance               \
#                        mean median count         std      mean median count
# workout_type
# Cricket          478.580645  512.0    93  286.817937  5.283763  5.150    93
# Freestyle        502.312500  535.0    96  295.745884  5.044792  4.505    96
# Indoor Cycling   570.412500  617.0    80  304.768669  5.259000  5.050    80
# Open Water       469.824176  483.0    91  284.556442  5.180659  4.660    91
# Outdoor Cycling  463.941176  422.0    85  278.997114  5.444000  5.570    85
# Outdoor Running  463.432099  438.0    81  272.649406  5.048025  4.500    81
# Pool Swimming    510.936170  517.0    94  290.626532  5.368085  4.840    94
# Trail Run        512.244444  524.0    90  293.682635  5.148000  5.145    90
# Treadmill        507.275510  520.5    98  291.104005  4.999898  4.730    98
# Trekking         479.021277  459.0    94  292.347046  5.278617  5.250    94
# ...

# %% [markdown]
# For this exam i spend 3 and half hours straight which is not more than the first exam for me and spend total of 11 hours and i didn't did in one sitting because of my previous mistake of doing simple mistake in the code with the letter i was very careful this time and most of the question was not hard but still if i choose the hardest one i will choose the question c because for some  reason i should have run all the code again from the beginning so even with the correct code i was not getting the output which took me few time to find.And the easiest part was converting activity_day into a datetime format and the removing spaces.I think we should have spend more timeon missing data percentage list.
#
#
#      And honestly i am really happy and thankful with all the quizes and exam we are doing in python i really have a desire to be good in atleast one of the programming language and with data visualization with the lots of code work that we are doing is helping me out.
